# %%
import rdflib
from rdflib import Graph, Literal, Namespace, RDF, URIRef, RDFS, XSD
from rdflib.namespace import DC, RDFS, SKOS
from rdflib.util import guess_format
import pprint
import django
django.setup()
from vocabs.models import *
import re

# %%
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")
DC = Namespace("http://purl.org/dc/elements/1.1/")
DCT = Namespace("http://purl.org/dc/terms/")
RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
OWL = Namespace("http://www.w3.org/2002/07/owl#")
VOCABS = Namespace("https://vocabs.acdh.oeaw.ac.at/create-concept-scheme/")

# %%
myfilettl = "test.ttl"
myfilerdf = "test.rdf"
skosifiedttl = "output.ttl"

# %%
class SkosImporter(object):
    # add main language for a vocab
    
    def __init__(self, file):
        self.file = file
        
    def graph_read(self, format=None):
        g = Graph()
        g.bind('skos', SKOS)
        g.bind('dc', DC)
        g.bind('dct', DCT)
        g.bind('rdfs', RDFS)
        g.bind('owl', OWL)
        g.parse(self.file, format=format)
        return g
    
    def parseCs(self, format=None):
        concept_scheme = {}
        g = self.graph_read(format=format)
        for cs in g.subjects(RDF.type, SKOS.ConceptScheme):
            concept_scheme["identifier"] = str(cs)
            for csLabel in g.preferredLabel(cs):
                concept_scheme["label"] = str(csLabel[1])
        return concept_scheme
        
        
    def parseConcepts(self, format=None):
        resources = []
        g = self.graph_read(format=format)
#         concept_scheme = ''
#         concept_scheme_label = ''
#         for cs in g.subjects(RDF.type, SKOS.ConceptScheme):
#             concept_scheme = str(cs)
#             for csLabel in g.preferredLabel(cs):
#                 concept_scheme_label = str(csLabel[1])
                #print(concept_scheme_label)
        for concept in g.subjects(RDF.type, SKOS.Concept):
            concept_desc = {}
            concept_desc["legacy_id"] = str(concept)
#             for prefLabel in g.objects(concept, SKOS.prefLabel):
#                 concept_desc["prefLabel"] = str(prefLabel)
            
            #Pref Labels
            pref_labels = []
            for prefLabelvar in g.preferredLabel(concept):
                prefLabel = {}
                prefLabel["label"] = str(prefLabelvar[1])
                lang = re.search("lang='(.{2,3})'", str(prefLabelvar))
                if lang is not None:
                    prefLabel["lang"] = lang.group(1)
                pref_labels.append(prefLabel)
            concept_desc["prefLabel"] = pref_labels
            
            #ALt Labels
            alt_labels =[]
            for altLabel in g.objects(concept, SKOS.altLabel):
                #print(altLabel)
                label = {}
                label["label"] = str(altLabel)
                lang = re.search("lang='(.{2,3})'", altLabel)
                if lang is not None:
                    label["lang"] = lang.group(1)
                alt_labels.append(label)
                
                
            concept_desc["altLabel"] = alt_labels
            for inScheme in g.objects(concept, SKOS.inScheme):
                concept_desc["inScheme"] = str(inScheme)
            for broader in g.objects(concept, SKOS.broader):
                concept_desc["broader"] = str(broader)
            for narrower in g.objects(concept, SKOS.narrower):
                concept_desc["narrower"] = str(narrower)
            for definition in g.objects(concept, SKOS.definition):
                concept_desc["definition"] = str(definition)
            for note in g.objects(concept, SKOS.note):
                concept_desc["note"] = str(note)
            for scopeNote in g.objects(concept, SKOS.scopeNote):
                concept_desc["scopeNote"] = str(scopeNote)
            for exactMatch in g.objects(concept, SKOS.exactMatch):
                concept_desc["exactMatch"] = str(exactMatch)
            for source in g.objects(concept, SKOS.source):
                concept_desc["source"] = str(source)
            for notation in g.objects(concept, SKOS.notation):
                concept_desc["notation"] = str(notation)
            for creator in g.objects(concept, DC.creator):
                concept_desc["creator"] = str(creator)
#             for pred, obj in g.predicate_objects(concept):
#                 concept_desc[str(pred)] = str(obj)
            resources.append(concept_desc)
        
        return resources
    
    
    def uploadRdf(self, format=None):
        cs_data = self.parseCs(format=format)
        concepts_data = self.parseConcepts(format=format)
        cs_uri = cs_data.get("identifier")
        cs_label = cs_data.get("label")
        cs = SkosConceptScheme.objects.create(identifier=cs_uri, title=cs_label, created_by=User.objects.get(username=''))
        cs.save
        # dealing with concepts
        for concept in concepts_data:
            concept_legacyid = concept.get("legacy_id")
            concept_inScheme = concept.get("inScheme", "None")
            concept_definition = concept.get("definition", "None")
            concept_notation = concept.get("notation", "None")
            concept_creator = concept.get("creator", "None")
            for prefLabel in concept.get("prefLabel"):
                concept_prefLabel = prefLabel.get("label")
                concept_prefLabel_lang = prefLabel.get("lang")
            new_concept = SkosConcept.objects.create(
                pref_label=concept_prefLabel, legacy_id=concept_legacyid,
                pref_label_lang=concept_prefLabel_lang, scheme=SkosConceptScheme.objects.get(identifier=concept_inScheme),
                notation=concept_notation, created_by=User.objects.get(username=''))
            new_concept.save()
        for concept in concepts_data:          
            if concept.get("broader") is not None:
                concept_broader = concept.get("broader")
                update_concept = SkosConcept.objects.filter(legacy_id=concept.get("legacy_id")).update(broader_concept=SkosConcept.objects.get(legacy_id=concept_broader))
        # need to rebuild tree
        mytree = SkosConcept.objects.rebuild()
        return mytree
       
# separate import of relationships

# %%
myimport = SkosImporter(skosifiedttl)
myimport.parseCs(format="ttl")
# Out:
# {'identifier': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#  'label': 'DHA Taxonomy Import Relationships'}

# %%
# format default is rdf, if ttl must be passed as format="ttl"
myimport.parseConcepts(format="ttl")
# Out:
# [{'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept36',
#   'prefLabel': [{'label': 'NER', 'lang': 'en'}],
#   'altLabel': [{'label': 'Named Entity Recognition'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept33',
#   'definition': 'a process of identifying mentions of individuals/entities in a text',
#   'notation': 'ner',
#   'creator': 'ACDH-OEAW Team'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept4',
#   'prefLabel': [{'label': 'RDF', 'lang': 'en'}],
#   'altLabel': [{'label': 'Resource Description Framework'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept1',
#   'definition': 'a group of W3C specifications designed as a metadata data model to provide interoperability between applications that exchange machine-understandable information on the Web. It is used as a general method for conceptual description or modeling of information.',
#   'notation': 'rdf'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept28',
#   'prefLabel': [{'label': 'historical text', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept23',
#   'definition': 'any text created in the past',
#   'notation': 'historical-text',
#   'creator': 'ACDH-OEAW Team'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept3',
#   'prefLabel': [{'label': 'FOAF', 'lang': 'en'}],
#   'altLabel': [{'label': 'Friend Of A Friend'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept1',
#   'definition': 'a machine-readable ontology describing persons, their activities and their relations to other people and objects',
#   'notation': 'foaf'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept23',
#   'prefLabel': [{'label': 'language resource', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'narrower': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept26',
#   'definition': 'a language resource is any physical or digital item that is a product of language documentation, description, or development or is a tool that specifically supports the creation and use of such products',
#   'notation': 'historical-resource'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept32',
#   'prefLabel': [{'label': 'Folia', 'lang': 'en'}],
#   'altLabel': [{'label': 'Linguistic annotation Folia'},
#    {'label': 'Format for Linguistic Annotation'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept31',
#   'definition': 'an XML-based annotation format, suitable for the representation of linguistically annotated language resources',
#   'notation': 'folia'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept5',
#   'prefLabel': [{'label': 'SKOS', 'lang': 'en'}],
#   'altLabel': [{'label': 'Simple Knowledge Organisation System'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept1',
#   'definition': 'a W3C recommendation format designed for the representation of thesauri, classification schemes, taxonomies, subject-heading systems, or any other type of structured controlled vocabulary',
#   'notation': 'skos'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept20',
#   'prefLabel': [{'label': 'copyright and licensing', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'definition': 'information about rights and conditions of use and distribution of resources',
#   'notation': 'copyrights',
#   'creator': 'ACDH-OEAW Team'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept30',
#   'prefLabel': [{'label': 'treebank', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept23',
#   'definition': 'collections of texts (or just sentences) annotated with complete syntactic structure',
#   'notation': 'treebank'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept17',
#   'prefLabel': [{'label': 'TEI', 'lang': 'en'}],
#   'altLabel': [{'label': 'Text Encoding Initiative'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept31',
#   'definition': 'a set of guidelines which specify encoding methods for machine-readable texts, chiefly in the humanities, social sciences and linguistics',
#   'notation': 'tei'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept34',
#   'prefLabel': [{'label': 'entity linking', 'lang': 'en'}],
#   'altLabel': [{'label': 'Named Entity Linking'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept33',
#   'note': 'the task of determining the identity of entities mentioned in the text that requires a knowledge base containing the entities to which entity mentions can be linked',
#   'notation': 'entity-linking'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept33',
#   'prefLabel': [{'label': 'NLP', 'lang': 'en'}],
#   'altLabel': [{'label': 'Natural Language Processing'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'narrower': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept35',
#   'definition': 'tools and methods to process (analyse, enrich, transform) language resources',
#   'notation': 'nlp',
#   'creator': 'ACDH-OEAW Team'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept24',
#   'prefLabel': [{'label': 'archaeology', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'definition': 'the study of human history and prehistory through the excavation of sites and the analysis of artefacts and other physical remains',
#   'notation': 'archaeology'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept35',
#   'prefLabel': [{'label': 'lemmatisation', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept33',
#   'definition': 'a process of grouping together the different inflected forms of a word to its canonical form so that they can be analysed as a single item',
#   'notation': 'lemmatisation'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept1',
#   'prefLabel': [{'label': 'semantic web vocabularies', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'narrower': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept4',
#   'definition': 'machine-readable terminologies that define concepts and relationships used to describe and organize data on the web',
#   'notation': 'language-resource',
#   'creator': 'ACDH'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept21',
#   'prefLabel': [{'label': 'activities', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'notation': 'activities'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept29',
#   'prefLabel': [{'label': 'lexical resource', 'lang': 'en'}],
#   'altLabel': [{'label': 'dictionary'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept23',
#   'definition': 'a structured list of words or multi-word expressions providing reference information about their meaning, translations in other languages, pronunciation, origin, usage etc.',
#   'exactMatch': 'http://dbpedia.org/resource/Dictionary',
#   'notation': 'lexical-resource',
#   'creator': 'ACDH-OEAW Team'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept27',
#   'prefLabel': [{'label': 'historical language', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept23',
#   'definition': 'a language that is spoken in a historical period, but that is distinct from its modern form; that is, it is a form of language historically attested to from the past which has evolved into more modern forms',
#   'notation': 'historical-language'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept26',
#   'prefLabel': [{'label': 'corpus', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept23',
#   'definition': 'a large and structured set of texts electronically stored and processed',
#   'notation': 'corpus-1'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept31',
#   'prefLabel': [{'label': 'text encoding', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'narrower': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept17',
#   'definition': 'the representation of printed texts in digital format',
#   'notation': 'text-encoding',
#   'creator': 'ACDH-OEAW Team'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept2',
#   'prefLabel': [{'label': 'CIDOC CRM', 'lang': 'en'}],
#   'altLabel': [{'label': 'Comité international pour la documentation: Conceptual Reference Model'}],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'broader': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept1',
#   'definition': 'a machine-readable ontology that provides definitions and a formal structure for describing general (top-level) concepts and relationships; used mainly in cultural heritage domain',
#   'exactMatch': 'http://d-nb.info/gnd/1073990826',
#   'notation': 'cidoc-crm'},
#  {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels#concept25',
#   'prefLabel': [{'label': 'architecture', 'lang': 'en'}],
#   'altLabel': [],
#   'inScheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-import-rels',
#   'definition': 'both the process and the product of planning, designing, and constructing buildings and other physical structures',
#   'notation': 'architecture'}]

# %%
myimport.uploadRdf(format="ttl")
