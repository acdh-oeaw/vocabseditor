# %%
import rdflib
from rdflib import Graph, Literal, Namespace, RDF, URIRef, RDFS, XSD
from rdflib.namespace import DC, RDFS, SKOS
from rdflib.util import guess_format
import pprint
import django
django.setup()
from vocabs.models import *
import re

# %%
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")
DC = Namespace("http://purl.org/dc/elements/1.1/")
DCT = Namespace("http://purl.org/dc/terms/")
RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
OWL = Namespace("http://www.w3.org/2002/07/owl#")
VOCABS = Namespace("https://vocabs.acdh.oeaw.ac.at/create-concept-scheme/")

# %%
myfilettl = "test.ttl"
myfilerdf = "archecategory.rdf"
skosifiedttl = "output.ttl"
dhade = "dha-de.rdf"

# %%
class SkosImporter(object):
    """
    Perform a file parsing and importing SKOS data in database
    """

    def __init__(self, file, file_format=None, language=None):
        self.file = file
        self.file_format = file_format
        self.language = language

    def _graph_read(self):
        """Parse a file in RDF Graph"""
        g = Graph()
        g.bind('skos', SKOS)
        g.bind('dc', DC)
        g.bind('dct', DCT)
        g.bind('rdfs', RDFS)
        g.parse(self.file, format=self.file_format)
        return g

    def parse_triples(self):
        concept_scheme = {}
        g = self._graph_read()
        if (None, RDF.type, SKOS.ConceptScheme) in g:
            for x in g.subjects(RDF.type, SKOS.ConceptScheme):
                concept_scheme["identifier"] = str(x)
                for title in g.preferredLabel(x):
                    concept_scheme["title"] = str(title[1])
        else:
            raise ValueError("Graph doesn't have a Concept Scheme")
        if (None, RDF.type, SKOS.Concept) in g:
            concepts = []
            for x in g.subjects(RDF.type, SKOS.Concept):
                concept = {}
                concept["legacy_id"] = str(x)
                # pref labels
                pref_labels = []
                for pref_label in g.preferredLabel(x):
                    label = {}
                    label["label"] = str(pref_label[1])
                    label["lang"] = str(pref_label[1].language)
                    pref_labels.append(label)
                concept["pref_label"] = pref_labels

                for scheme in g.objects(x, SKOS.inScheme):
                    concept["scheme"] = str(scheme)
                for notation in g.objects(x, SKOS.notation):
                    concept["notation"] = str(notation)
                for creator in g.objects(x, DC.creator):
                    concept["creator"] = str(creator)
                for contributor in g.objects(x, DC.contributor):
                    concept["contributor"] = str(contributor)
                for broader_concept in g.objects(x, SKOS.broader):
                    concept["broader_concept"] = str(broader_concept)
                alt_labels = [] 
                for alt_label in g.objects(x, SKOS.altLabel):
                    label = {}
                    label["label"] = str(alt_label)
                    label["lang"] = alt_label.language
                    alt_labels.append(label)
                concept["alt_label"] = alt_labels
                concepts.append(concept)
            concept_scheme["has_concepts"] = concepts
        return concept_scheme

    def upload_data(self):
        """
        Creates and saves concepts scheme and its concepts in a database
        """
        concept_scheme = self.parse_triples()
        concept_scheme_uri = concept_scheme.get("identifier")
        concept_scheme_title = concept_scheme.get("title")
        concept_scheme_has_concepts = concept_scheme.get("has_concepts")
        concept_scheme = SkosConceptScheme.objects.create(
            identifier=concept_scheme_uri,
            title=concept_scheme_title, created_by=User.objects.get(username='kzaytseva')
            )
        concept_scheme.save()
        for concept in concept_scheme_has_concepts:
            concept_legacy_id = concept.get("legacy_id")
            concept_inscheme = concept.get("scheme")
            concept_notation = concept.get("notation", "")
            concept_creator = concept.get("creator", "")
            concept_contributor = concept.get("contributor", "")
            concept_alt_labels = concept.get("alt_label")
            main_pref_label = {}
            other_pref_labels = []
            for pref_label in concept.get("pref_label"):
                if  pref_label.get("lang") == self.language:
                    main_pref_label["label"] = pref_label.get("label")
                    main_pref_label["lang"] = pref_label.get("lang")
                else:
                    other_pref_label = {}
                    other_pref_label["label"] = pref_label.get("label", "other label")
                    other_pref_label["lang"] = pref_label.get("lang", "tes") 
                    other_pref_labels.append(other_pref_label)
            concept_pref_label = main_pref_label.get("label", "no label in this language")
            concept_pref_label_lang = main_pref_label.get("lang", self.language)
            new_concept = SkosConcept.objects.create(
                legacy_id=concept_legacy_id,
                scheme=SkosConceptScheme.objects.get(identifier=concept_inscheme),
                pref_label=concept_pref_label, pref_label_lang=concept_pref_label_lang,
                notation=concept_notation, creator=concept_creator,
                contributor=concept_contributor, created_by=User.objects.get(username='kzaytseva')
                )
            new_concept.save()
            if len(other_pref_labels) > 0:
                for other in other_pref_labels:
                    other_label = ConceptLabel.objects.create(concept=new_concept, name=other.get("label"), language=other.get("lang"), label_type="prefLabel")
                    other_label.save()
            if  len(concept_alt_labels) > 0:
                for alt in concept_alt_labels:
                    alt_label = ConceptLabel.objects.create(concept=new_concept, name=alt.get("label"), language=alt.get("lang"), label_type="altLabel")
                    alt_label.save()
            
        # add relationships
        for concept in concept_scheme_has_concepts:
            if concept.get("broader_concept") is not None:
                update_concept = SkosConcept.objects.filter(
                    legacy_id=concept.get("legacy_id")).update(
                    broader_concept=SkosConcept.objects.get(legacy_id=concept.get("broader_concept"))
                    )
            else:
                pass
        return SkosConcept.objects.rebuild()

# %%
mydata = SkosImporter(dhade, language="de")
mydata.parse_triples()
# Out:
# {'identifier': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#  'title': 'DHA Taxonomy',
#  'has_concepts': [{'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept20',
#    'pref_label': [{'label': 'copyright and licensing', 'lang': 'en'},
#     {'label': 'Urheberrecht und Lizenzierung', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'copyrights',
#    'creator': 'ACDH-OEAW Team',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept26',
#    'pref_label': [{'label': 'Korpus', 'lang': 'de'},
#     {'label': 'corpus', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'corpus-1',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept23',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept4',
#    'pref_label': [{'label': 'RDF', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'rdf',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept1',
#    'alt_label': [{'label': 'Resource Description Framework', 'lang': 'en'},
#     {'label': 'RDF', 'lang': 'de'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept23',
#    'pref_label': [{'label': 'Sprachressource', 'lang': 'en'},
#     {'label': 'language resource', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'historical-resource',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept30',
#    'pref_label': [{'label': 'treebank', 'lang': 'en'},
#     {'label': 'Treebank', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'treebank',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept23',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept35',
#    'pref_label': [{'label': 'lemmatisation', 'lang': 'en'},
#     {'label': 'Lemmatisierung', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'lemmatisation',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept33',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept5',
#    'pref_label': [{'label': 'SKOS', 'lang': 'en'},
#     {'label': 'SKOS', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'skos',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept1',
#    'alt_label': [{'label': 'Simple Knowledge Organisation System',
#      'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept25',
#    'pref_label': [{'label': 'Architektur', 'lang': 'de'},
#     {'label': 'architecture', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'architecture',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept36',
#    'pref_label': [{'label': 'NER', 'lang': 'en'},
#     {'label': 'NER', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'ner',
#    'creator': 'ACDH-OEAW Team',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept33',
#    'alt_label': [{'label': 'Named Entity Recognition', 'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept32',
#    'pref_label': [{'label': 'Folia', 'lang': 'de'},
#     {'label': 'Folia', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'folia',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept31',
#    'alt_label': [{'label': 'Format for Linguistic Annotation', 'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept21',
#    'pref_label': [{'label': 'Aktivitäten', 'lang': 'de'},
#     {'label': 'activities', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'activities',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept31',
#    'pref_label': [{'label': 'text encoding', 'lang': 'en'},
#     {'label': 'text encoding', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'text-encoding',
#    'creator': 'ACDH-OEAW Team',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept1',
#    'pref_label': [{'label': 'semantische Web vokabulare', 'lang': 'de'},
#     {'label': 'semantic web vocabularies', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'language-resource',
#    'creator': 'ACDH',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept17',
#    'pref_label': [{'label': 'TEI', 'lang': 'de'},
#     {'label': 'TEI', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'tei',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept31',
#    'alt_label': [{'label': 'Text Encoding Initiative', 'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept27',
#    'pref_label': [{'label': 'historical language', 'lang': 'en'},
#     {'label': 'historische Sprache', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'historical-language',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept23',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept3',
#    'pref_label': [{'label': 'FOAF', 'lang': 'de'},
#     {'label': 'FOAF', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'foaf',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept1',
#    'alt_label': [{'label': 'Friend Of A Friend', 'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept24',
#    'pref_label': [{'label': 'archaeology', 'lang': 'en'},
#     {'label': 'Archäologie', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'archaeology',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept28',
#    'pref_label': [{'label': 'historischer Text', 'lang': 'de'},
#     {'label': 'historical text', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'historical-text',
#    'creator': 'ACDH-OEAW Team',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept23',
#    'alt_label': []},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept2',
#    'pref_label': [{'label': 'CIDOC CRM', 'lang': 'de'},
#     {'label': 'CIDOC CRM', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'cidoc-crm',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept1',
#    'alt_label': [{'label': 'Comité international pour la documentation: Conceptual Reference Model',
#      'lang': 'fr'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept33',
#    'pref_label': [{'label': 'NLP', 'lang': 'de'},
#     {'label': 'NLP', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'nlp',
#    'creator': 'ACDH-OEAW Team',
#    'alt_label': [{'label': 'Natural Language Processing', 'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept29',
#    'pref_label': [{'label': 'lexical resource', 'lang': 'en'},
#     {'label': 'lexikalische Ressource', 'lang': 'de'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'lexical-resource',
#    'creator': 'ACDH-OEAW Team',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept23',
#    'alt_label': [{'label': 'dictionary', 'lang': 'en'}]},
#   {'legacy_id': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept34',
#    'pref_label': [{'label': 'Entity-Verknüpfung', 'lang': 'de'},
#     {'label': 'entity linking', 'lang': 'en'}],
#    'scheme': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch',
#    'notation': 'entity-linking',
#    'broader_concept': 'https://vocabs.acdh.oeaw.ac.at/dha-taxonomy-deutsch#concept33',
#    'alt_label': [{'label': 'Named Entity Linking', 'lang': 'en'}]}]}

# %%
mydata.upload_data()
